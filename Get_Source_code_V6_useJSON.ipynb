# %%
import os
import ast
import json
from pycparser import c_parser, parse_file

def extract_python_info(file_path):
    with open(file_path, 'r', encoding='utf-8') as source:
        try:
            tree = ast.parse(source.read())
        except SyntaxError as e:
            print(f"Syntax error in {file_path}: {e}")
            return None

        functions = [node.name for node in ast.walk(tree) if isinstance(node, ast.FunctionDef)]
        classes = [node.name for node in ast.walk(tree) if isinstance(node, ast.ClassDef)]
        
        return {
            'file_path': file_path,
            'functions': functions,
            'classes': classes
        }

def extract_c_info(file_path):
    try:
        ast = parse_file(file_path, use_cpp=True)
    except Exception as e:
        print(f"Error parsing {file_path}: {e}")
        return None

    functions = [func.decl.name for func in ast.ext if func.__class__.__name__ == 'FuncDef']
    classes = []  # C doesn't have classes

    return {
        'file_path': file_path,
        'functions': functions,
        'classes': classes
    }

# %%
def record_code_elements(root_dir):
    data = []

    for dir_name, sub_dirs, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.py'):
                info = extract_python_info(os.path.join(dir_name, file))
                if info:
                    data.append(info)
            elif file.endswith('.c'):
                info = extract_c_info(os.path.join(dir_name, file))
                if info:
                    data.append(info)

    with open('code_elements.json', 'w') as f:
        json.dump(data, f, indent=4)

# %%
record_code_elements('../pytorch')
# Out:
# ../pytorch/caffe2/mobile/contrib/libopencl-stub/src/libopencl.c:12:10: fatal error: libopencl.h: No such file or directory
#    12 | #include "libopencl.h"
#       |          ^~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/caffe2/mobile/contrib/libvulkan-stub/src/libvulkan-stub.c:23:10: fatal error: libvulkan-stub.h: No such file or directory
#    23 | #include "libvulkan-stub.h"
#       |          ^~~~~~~~~~~~~~~~~~
# compilation terminated.
# Error parsing ../pytorch/caffe2/mobile/contrib/libopencl-stub/src/libopencl.c: Command '['cpp', '../pytorch/caffe2/mobile/contrib/libopencl-stub/src/libopencl.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/caffe2/mobile/contrib/libvulkan-stub/src/libvulkan-stub.c: Command '['cpp', '../pytorch/caffe2/mobile/contrib/libvulkan-stub/src/libvulkan-stub.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/caffe2/mobile/contrib/nnapi/dlnnapi.c: /usr/include/dlfcn.h:58:54: before: __attribute__
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/deps/clog/src/clog.c:30:10: fatal error: clog.h: No such file or directory
#    30 | #include <clog.h>
#       |          ^~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/add.c:15:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    15 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/average-pooling.c:17:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    17 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/channel-shuffle.c:15:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    15 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/clamp.c:15:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    15 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/convolution.c:17:10: fatal error: fxdiv.h: No such file or directory
#    17 | #include <fxdiv.h>
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/deconvolution.c:16:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    16 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/fully-connected-sparse.c:16:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    16 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/fully-connected.c:16:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    16 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/global-average-pooling.c:15:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    15 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/hardsigmoid.c:15:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    15 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/hardswish.c:15:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    15 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/indirection.c:11:10: fatal error: fxdiv.h: No such file or directory
#    11 | #include <fxdiv.h>
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/init.c:19:10: fatal error: cpuinfo.h: No such file or directory
#    19 | #include <cpuinfo.h>
#       |          ^~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/leaky-relu.c:15:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    15 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/max-pooling.c:17:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    17 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/operator-delete.c:11:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    11 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/operator-run.c:14:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    14 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sigmoid.c:15:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    15 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/softargmax.c:15:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    15 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/tanh.c:15:10: fatal error: pytorch_qnnpack.h: No such file or directory
#    15 | #include <pytorch_qnnpack.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/hgemm/8x8-neonfp16arith.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/mp8x9p8q-neon.c:11:10: fatal error: arm_neon.h: No such file or directory
#    11 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/mp8x9p8q-sse2.c:13:10: fatal error: qnnpack/q8avgpool.h: No such file or directory
#    13 | #include <qnnpack/q8avgpool.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8x9-neon.c:11:10: fatal error: arm_neon.h: No such file or directory
#    11 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/deps/clog/src/clog.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/deps/clog/src/clog.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/add.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/add.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/average-pooling.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/average-pooling.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/channel-shuffle.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/channel-shuffle.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/clamp.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/clamp.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/convolution.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/convolution.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/deconvolution.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/deconvolution.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/fully-connected-sparse.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/fully-connected-sparse.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/fully-connected.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/fully-connected.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/global-average-pooling.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/global-average-pooling.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/hardsigmoid.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/hardsigmoid.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/hardswish.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/hardswish.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/indirection.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/indirection.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/init.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/init.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/leaky-relu.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/leaky-relu.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/max-pooling.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/max-pooling.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/operator-delete.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/operator-delete.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/operator-run.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/operator-run.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sigmoid.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sigmoid.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/softargmax.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/softargmax.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/tanh.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/tanh.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/hgemm/8x8-neonfp16arith.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/hgemm/8x8-neonfp16arith.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/mp8x9p8q-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/mp8x9p8q-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/mp8x9p8q-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/mp8x9p8q-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8x9-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8x9-neon.c']' returned non-zero exit status 1.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8x9-sse2.c:13:10: fatal error: qnnpack/q8avgpool.h: No such file or directory
#    13 | #include <qnnpack/q8avgpool.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8xm-neon.c:11:10: fatal error: arm_neon.h: No such file or directory
#    11 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8xm-sse2.c:13:10: fatal error: qnnpack/q8avgpool.h: No such file or directory
#    13 | #include <qnnpack/q8avgpool.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8conv/4x4c2-sse2.c:11:10: fatal error: qnnpack/q8conv.h: No such file or directory
#    11 | #include <qnnpack/q8conv.h>
#       |          ^~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8conv/4x8-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8conv/8x8-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-neon-per-channel.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-sse2-per-channel.c:11:10: fatal error: qnnpack/q8dwconv.h: No such file or directory
#    11 | #include <qnnpack/q8dwconv.h>
#       |          ^~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-sse2.c:11:10: fatal error: qnnpack/q8dwconv.h: No such file or directory
#    11 | #include <qnnpack/q8dwconv.h>
#       |          ^~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-neon-per-channel.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-sse2-per-channel.c:11:10: fatal error: qnnpack/q8dwconv.h: No such file or directory
#    11 | #include <qnnpack/q8dwconv.h>
#       |          ^~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-sse2.c:11:10: fatal error: qnnpack/q8dwconv.h: No such file or directory
#    11 | #include <qnnpack/q8dwconv.h>
#       |          ^~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/mp8x7p7q-neon.c:11:10: fatal error: arm_neon.h: No such file or directory
#    11 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/mp8x7p7q-sse2.c:13:10: fatal error: qnnpack/q8gavgpool.h: No such file or directory
#    13 | #include <qnnpack/q8gavgpool.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8x7-neon.c:11:10: fatal error: arm_neon.h: No such file or directory
#    11 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8x7-sse2.c:13:10: fatal error: qnnpack/q8gavgpool.h: No such file or directory
#    13 | #include <qnnpack/q8gavgpool.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8xm-neon.c:11:10: fatal error: arm_neon.h: No such file or directory
#    11 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8xm-sse2.c:13:10: fatal error: qnnpack/q8gavgpool.h: No such file or directory
#    13 | #include <qnnpack/q8gavgpool.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8x9-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8x9-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8xm-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8xm-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8xm-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8avgpool/up8xm-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8conv/4x4c2-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8conv/4x4c2-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8conv/4x8-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8conv/4x8-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8conv/8x8-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8conv/8x8-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-neon-per-channel.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-neon-per-channel.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-sse2-per-channel.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-sse2-per-channel.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/mp8x25-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-neon-per-channel.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-neon-per-channel.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-sse2-per-channel.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-sse2-per-channel.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8dwconv/up8x9-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/mp8x7p7q-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/mp8x7p7q-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/mp8x7p7q-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/mp8x7p7q-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8x7-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8x7-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8x7-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8x7-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8xm-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8xm-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8xm-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gavgpool/up8xm-sse2.c']' returned non-zero exit status 1.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/2x4c8-sse2.c:11:10: fatal error: qnnpack/q8gemm.h: No such file or directory
#    11 | #include <qnnpack/q8gemm.h>
#       |          ^~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x-sumrows-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x4c2-dq-sse2.c:11:10: fatal error: qnnpack/q8gemm.h: No such file or directory
#    11 | #include <qnnpack/q8gemm.h>
#       |          ^~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x4c2-sse2.c:11:10: fatal error: qnnpack/q8gemm.h: No such file or directory
#    11 | #include <qnnpack/q8gemm.h>
#       |          ^~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x8-dq-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x8-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x8c2-xzp-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/6x4-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/8x8-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm_sparse/8x4-packA-sse2.c:11:10: fatal error: qnnpack/q8gemm_sparse.h: No such file or directory
#    11 | #include <qnnpack/q8gemm_sparse.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm_sparse/8x4c1x4-dq-packedA-sse2.c:11:10: fatal error: qnnpack/q8gemm_sparse.h: No such file or directory
#    11 | #include <qnnpack/q8gemm_sparse.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm_sparse/8x4c1x4-dq-sse2.c:11:10: fatal error: qnnpack/q8gemm_sparse.h: No such file or directory
#    11 | #include <qnnpack/q8gemm_sparse.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8vadd/neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8vadd/sse2.c:11:10: fatal error: qnnpack/common.h: No such file or directory
#    11 | #include <qnnpack/common.h>
#       |          ^~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-neon.c:12:10: fatal error: arm_neon.h: No such file or directory
#    12 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-psimd.c:12:10: fatal error: psimd.h: No such file or directory
#    12 | #include <psimd.h>
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-scalar.c:13:10: fatal error: fp16/bitcasts.h: No such file or directory
#    13 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-sse2.c:14:10: fatal error: qnnpack/requantization-stubs.h: No such file or directory
#    14 | #include <qnnpack/requantization-stubs.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-neon.c:12:10: fatal error: arm_neon.h: No such file or directory
#    12 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-scalar.c:12:10: fatal error: fp16/bitcasts.h: No such file or directory
#    12 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-sse2.c:14:10: fatal error: fp16/bitcasts.h: No such file or directory
#    14 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-sse4.c:14:10: fatal error: fp16/bitcasts.h: No such file or directory
#    14 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/2x4c8-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/2x4c8-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x-sumrows-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x-sumrows-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x4c2-dq-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x4c2-dq-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x4c2-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x4c2-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x8-dq-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x8-dq-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x8-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x8-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x8c2-xzp-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/4x8c2-xzp-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/6x4-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/6x4-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/8x8-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm/8x8-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm_sparse/8x4-packA-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm_sparse/8x4-packA-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm_sparse/8x4c1x4-dq-packedA-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm_sparse/8x4c1x4-dq-packedA-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm_sparse/8x4c1x4-dq-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8gemm_sparse/8x4c1x4-dq-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8vadd/neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8vadd/neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8vadd/sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/q8vadd/sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-psimd.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-psimd.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/fp32-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-sse4.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-sse4.c']' returned non-zero exit status 1.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-ssse3.c:14:10: fatal error: fp16/bitcasts.h: No such file or directory
#    14 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-neon.c:12:10: fatal error: arm_neon.h: No such file or directory
#    12 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-psimd.c:12:10: fatal error: psimd.h: No such file or directory
#    12 | #include <psimd.h>
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-scalar.c:12:10: fatal error: fp16/bitcasts.h: No such file or directory
#    12 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-sse2.c:14:10: fatal error: fp16/bitcasts.h: No such file or directory
#    14 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-sse4.c:14:10: fatal error: fp16/bitcasts.h: No such file or directory
#    14 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-ssse3.c:14:10: fatal error: fp16/bitcasts.h: No such file or directory
#    14 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-neon.c:12:10: fatal error: arm_neon.h: No such file or directory
#    12 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-scalar.c:12:10: fatal error: fp16/bitcasts.h: No such file or directory
#    12 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-sse2.c:14:10: fatal error: fp16/bitcasts.h: No such file or directory
#    14 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-sse4.c:14:10: fatal error: fp16/bitcasts.h: No such file or directory
#    14 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-ssse3.c:14:10: fatal error: fp16/bitcasts.h: No such file or directory
#    14 | #include <fp16/bitcasts.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sconv/6x8-psimd.c:9:10: fatal error: psimd.h: No such file or directory
#     9 | #include <psimd.h>
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sdwconv/up4x9-psimd.c:9:10: fatal error: psimd.h: No such file or directory
#     9 | #include <psimd.h>
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sgemm/5x8-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sgemm/6x8-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sgemm/6x8-psimd.c:9:10: fatal error: psimd.h: No such file or directory
#     9 | #include <psimd.h>
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8clamp/neon.c:11:10: fatal error: arm_neon.h: No such file or directory
#    11 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8clamp/sse2.c:13:10: fatal error: qnnpack/u8clamp.h: No such file or directory
#    13 | #include <qnnpack/u8clamp.h>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8lut32norm/scalar.c:11:10: fatal error: fxdiv.h: No such file or directory
#    11 | #include <fxdiv.h>
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/16x9p8q-neon.c:11:10: fatal error: arm_neon.h: No such file or directory
#    11 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/16x9p8q-sse2.c:13:10: fatal error: qnnpack/u8maxpool.h: No such file or directory
#    13 | #include <qnnpack/u8maxpool.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/sub16-neon.c:11:10: fatal error: arm_neon.h: No such file or directory
#    11 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/sub16-sse2.c:13:10: fatal error: qnnpack/u8maxpool.h: No such file or directory
#    13 | #include <qnnpack/u8maxpool.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8rmax/neon.c:11:10: fatal error: arm_neon.h: No such file or directory
#    11 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8rmax/sse2.c:13:10: fatal error: qnnpack/u8rmax.h: No such file or directory
#    13 | #include <qnnpack/u8rmax.h>
#       |          ^~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8lut/scalar.c:11:10: fatal error: qnnpack/x8lut.h: No such file or directory
#    11 | #include <qnnpack/x8lut.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x2-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x2-sse2.c:11:10: fatal error: qnnpack/x8zip.h: No such file or directory
#    11 | #include <qnnpack/x8zip.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x3-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x3-sse2.c:11:10: fatal error: qnnpack/x8zip.h: No such file or directory
#    11 | #include <qnnpack/x8zip.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x4-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x4-sse2.c:11:10: fatal error: qnnpack/x8zip.h: No such file or directory
#    11 | #include <qnnpack/x8zip.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/xm-neon.c:9:10: fatal error: arm_neon.h: No such file or directory
#     9 | #include <arm_neon.h>
#       |          ^~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/xm-sse2.c:11:10: fatal error: qnnpack/x8zip.h: No such file or directory
#    11 | #include <qnnpack/x8zip.h>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8avgpool/mp8x9p8q-sse2.c:4:10: fatal error: q8avgpool/mp8x9p8q-sse2.c: No such file or directory
#     4 | #include <q8avgpool/mp8x9p8q-sse2.c>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8avgpool/up8x9-sse2.c:4:10: fatal error: q8avgpool/up8x9-sse2.c: No such file or directory
#     4 | #include <q8avgpool/up8x9-sse2.c>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-ssse3.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/gemmlowp-ssse3.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-psimd.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-psimd.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-sse4.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-sse4.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-ssse3.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/precise-ssse3.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-sse4.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-sse4.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-ssse3.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/requantization/q31-ssse3.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sconv/6x8-psimd.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sconv/6x8-psimd.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sdwconv/up4x9-psimd.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sdwconv/up4x9-psimd.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sgemm/5x8-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sgemm/5x8-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sgemm/6x8-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sgemm/6x8-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sgemm/6x8-psimd.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/sgemm/6x8-psimd.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8clamp/neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8clamp/neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8clamp/sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8clamp/sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8lut32norm/scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8lut32norm/scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/16x9p8q-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/16x9p8q-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/16x9p8q-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/16x9p8q-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/sub16-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/sub16-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/sub16-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8maxpool/sub16-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8rmax/neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8rmax/neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8rmax/sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/u8rmax/sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8lut/scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8lut/scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x2-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x2-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x2-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x2-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x3-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x3-neon.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x3-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x3-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x4-neon.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/src/x8zip/x4-neon.c']' returned non-zero exit status 1.
# ...
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8dwconv/up8x9-sse2-per-channel.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8dwconv/up8x9-sse2-per-channel.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8dwconv/up8x9-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8dwconv/up8x9-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gavgpool/mp8x7p7q-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gavgpool/mp8x7p7q-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gavgpool/up8x7-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gavgpool/up8x7-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gavgpool/up8xm-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gavgpool/up8xm-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gemm/2x4c8-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gemm/2x4c8-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gemm/4x4c2-dq-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gemm/4x4c2-dq-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gemm/4x4c2-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gemm/4x4c2-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gemm_sparse/8x4c1x4-dq-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gemm_sparse/8x4c1x4-dq-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gemm_sparse/8x4c1x4-packed-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8gemm_sparse/8x4c1x4-packed-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8vadd/sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/q8vadd/sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/fp32-psimd.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/fp32-psimd.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/fp32-scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/fp32-scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/fp32-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/fp32-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/gemmlowp-scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/gemmlowp-scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/gemmlowp-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/gemmlowp-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/gemmlowp-sse4.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/gemmlowp-sse4.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/gemmlowp-ssse3.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/gemmlowp-ssse3.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/precise-psimd.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/precise-psimd.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/precise-scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/precise-scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/precise-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/precise-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/precise-sse4.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/precise-sse4.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/precise-ssse3.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/precise-ssse3.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-scalar.c']' returned non-zero exit status 1.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-sse2.c:4:10: fatal error: requantization/q31-sse2.c: No such file or directory
#     4 | #include <requantization/q31-sse2.c>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-sse4.c:4:10: fatal error: requantization/q31-sse4.c: No such file or directory
#     4 | #include <requantization/q31-sse4.c>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-ssse3.c:4:10: fatal error: requantization/q31-ssse3.c: No such file or directory
#     4 | #include <requantization/q31-ssse3.c>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/sgemm/6x8-psimd.c:3:10: fatal error: sgemm/6x8-psimd.c: No such file or directory
#     3 | #include <sgemm/6x8-psimd.c>
#       |          ^~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8clamp/sse2.c:4:10: fatal error: u8clamp/sse2.c: No such file or directory
#     4 | #include <u8clamp/sse2.c>
#       |          ^~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8lut32norm/scalar.c:3:10: fatal error: u8lut32norm/scalar.c: No such file or directory
#     3 | #include <u8lut32norm/scalar.c>
#       |          ^~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8maxpool/16x9p8q-sse2.c:4:10: fatal error: u8maxpool/16x9p8q-sse2.c: No such file or directory
#     4 | #include <u8maxpool/16x9p8q-sse2.c>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8maxpool/sub16-sse2.c:4:10: fatal error: u8maxpool/sub16-sse2.c: No such file or directory
#     4 | #include <u8maxpool/sub16-sse2.c>
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8rmax/sse2.c:4:10: fatal error: u8rmax/sse2.c: No such file or directory
#     4 | #include <u8rmax/sse2.c>
#       |          ^~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8lut/scalar.c:3:10: fatal error: x8lut/scalar.c: No such file or directory
#     3 | #include <x8lut/scalar.c>
#       |          ^~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/x2-sse2.c:4:10: fatal error: x8zip/x2-sse2.c: No such file or directory
#     4 | #include <x8zip/x2-sse2.c>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/x3-sse2.c:4:10: fatal error: x8zip/x3-sse2.c: No such file or directory
#     4 | #include <x8zip/x3-sse2.c>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/x4-sse2.c:4:10: fatal error: x8zip/x4-sse2.c: No such file or directory
#     4 | #include <x8zip/x4-sse2.c>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/xm-sse2.c:4:10: fatal error: x8zip/xm-sse2.c: No such file or directory
#     4 | #include <x8zip/xm-sse2.c>
#       |          ^~~~~~~~~~~~~~~~~
# compilation terminated.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-sse4.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-sse4.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-ssse3.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/requantization/q31-ssse3.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/sgemm/6x8-psimd.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/sgemm/6x8-psimd.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8clamp/sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8clamp/sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8lut32norm/scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8lut32norm/scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8maxpool/16x9p8q-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8maxpool/16x9p8q-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8maxpool/sub16-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8maxpool/sub16-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8rmax/sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/u8rmax/sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8lut/scalar.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8lut/scalar.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/x2-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/x2-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/x3-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/x3-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/x4-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/x4-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/xm-sse2.c: Command '['cpp', '../pytorch/aten/src/ATen/native/quantized/cpu/qnnpack/wrappers/x8zip/xm-sse2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/third_party/miniz-2.0.8/miniz.c: /usr/lib/gcc/x86_64-linux-gnu/11/include/stddef.h:416:28: before: __attribute__
# Error parsing ../pytorch/third_party/miniz-2.0.8/examples/example1.c: Command '['cpp', '../pytorch/third_party/miniz-2.0.8/examples/example1.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/third_party/miniz-2.0.8/examples/example2.c: Command '['cpp', '../pytorch/third_party/miniz-2.0.8/examples/example2.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/third_party/miniz-2.0.8/examples/example3.c: Command '['cpp', '../pytorch/third_party/miniz-2.0.8/examples/example3.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/third_party/miniz-2.0.8/examples/example4.c: Command '['cpp', '../pytorch/third_party/miniz-2.0.8/examples/example4.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/third_party/miniz-2.0.8/examples/example5.c: Command '['cpp', '../pytorch/third_party/miniz-2.0.8/examples/example5.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/third_party/miniz-2.0.8/examples/example6.c: Command '['cpp', '../pytorch/third_party/miniz-2.0.8/examples/example6.c']' returned non-zero exit status 1.
# Syntax error in ../pytorch/tools/autograd/templates/annotated_fn_args.py: invalid syntax (<unknown>, line 10)
# ../pytorch/third_party/miniz-2.0.8/examples/example1.c:4:10: fatal error: miniz.h: No such file or directory
#     4 | #include "miniz.h"
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/third_party/miniz-2.0.8/examples/example2.c:16:10: fatal error: miniz_zip.h: No such file or directory
#    16 | #include "miniz_zip.h"
#       |          ^~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/third_party/miniz-2.0.8/examples/example3.c:6:10: fatal error: miniz.h: No such file or directory
#     6 | #include "miniz.h"
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/third_party/miniz-2.0.8/examples/example4.c:3:10: fatal error: miniz_tinfl.h: No such file or directory
#     3 | #include "miniz_tinfl.h"
#       |          ^~~~~~~~~~~~~~~
# compilation terminated.
# ../pytorch/third_party/miniz-2.0.8/examples/example5.c:12:10: fatal error: miniz.h: No such file or directory
#    12 | #include "miniz.h"
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/third_party/miniz-2.0.8/examples/example6.c:10:10: fatal error: miniz.h: No such file or directory
#    10 | #include "miniz.h"
#       |          ^~~~~~~~~
# compilation terminated.
# ../pytorch/torch/csrc/dl.c:1:10: fatal error: Python.h: No such file or directory
#     1 | #include <Python.h>
#       |          ^~~~~~~~~~
# compilation terminated.
# ../pytorch/torch/csrc/stub.c:1:10: fatal error: Python.h: No such file or directory
#     1 | #include <Python.h>
#       |          ^~~~~~~~~~
# compilation terminated.
# Error parsing ../pytorch/torch/csrc/dl.c: Command '['cpp', '../pytorch/torch/csrc/dl.c']' returned non-zero exit status 1.
# Error parsing ../pytorch/torch/csrc/stub.c: Command '['cpp', '../pytorch/torch/csrc/stub.c']' returned non-zero exit status 1.
